# %% [markdown]
# # IConZIC

# %%
#@title Prepare the running enviroment
# %cd /content
# !git clone https://github.com/stop1one/IConZIC.git
# %cd /content/IConZIC
# !pip install -r requirements.txt
# Out:
# /content
# Cloning into 'VZIC'...
# remote: Enumerating objects: 390, done.
# remote: Counting objects: 100% (45/45), done.
# remote: Compressing objects: 100% (16/16), done.
# remote: Total 390 (delta 31), reused 30 (delta 29), pack-reused 345
# Receiving objects: 100% (390/390), 10.95 MiB | 19.27 MiB/s, done.
# Resolving deltas: 100% (152/152), done.
# /content/VZIC
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Collecting colorlog (from -r requirements.txt (line 1))
#   Downloading colorlog-6.7.0-py2.py3-none-any.whl (11 kB)
# Requirement already satisfied: nltk in /usr/local/lib/python3.10/dist-packages (from -r requirements.txt (line 2)) (3.8.1)
# Collecting transformers (from -r requirements.txt (line 3))
#   Downloading transformers-4.29.2-py3-none-any.whl (7.1 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 7.1/7.1 MB 25.1 MB/s eta 0:00:00
# Requirement already satisfied: torch in /usr/local/lib/python3.10/dist-packages (from -r requirements.txt (line 4)) (2.0.1+cu118)
# Requirement already satisfied: torchvision in /usr/local/lib/python3.10/dist-packages (from -r requirements.txt (line 5)) (0.15.2+cu118)
# Requirement already satisfied: click in /usr/local/lib/python3.10/dist-packages (from nltk->-r requirements.txt (line 2)) (8.1.3)
# Requirement already satisfied: joblib in /usr/local/lib/python3.10/dist-packages (from nltk->-r requirements.txt (line 2)) (1.2.0)
# Requirement already satisfied: regex>=2021.8.3 in /usr/local/lib/python3.10/dist-packages (from nltk->-r requirements.txt (line 2)) (2022.10.31)
# Requirement already satisfied: tqdm in /usr/local/lib/python3.10/dist-packages (from nltk->-r requirements.txt (line 2)) (4.65.0)
# Requirement already satisfied: filelock in /usr/local/lib/python3.10/dist-packages (from transformers->-r requirements.txt (line 3)) (3.12.0)
# Collecting huggingface-hub<1.0,>=0.14.1 (from transformers->-r requirements.txt (line 3))
#   Downloading huggingface_hub-0.14.1-py3-none-any.whl (224 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 224.5/224.5 kB 11.8 MB/s eta 0:00:00
# Requirement already satisfied: numpy>=1.17 in /usr/local/lib/python3.10/dist-packages (from transformers->-r requirements.txt (line 3)) (1.22.4)
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.10/dist-packages (from transformers->-r requirements.txt (line 3)) (23.1)
# Requirement already satisfied: pyyaml>=5.1 in /usr/local/lib/python3.10/dist-packages (from transformers->-r requirements.txt (line 3)) (6.0)
# Requirement already satisfied: requests in /usr/local/lib/python3.10/dist-packages (from transformers->-r requirements.txt (line 3)) (2.27.1)
# Collecting tokenizers!=0.11.3,<0.14,>=0.11.1 (from transformers->-r requirements.txt (line 3))
#   Downloading tokenizers-0.13.3-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (7.8 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 7.8/7.8 MB 28.9 MB/s eta 0:00:00
# Requirement already satisfied: typing-extensions in /usr/local/lib/python3.10/dist-packages (from torch->-r requirements.txt (line 4)) (4.5.0)
# Requirement already satisfied: sympy in /usr/local/lib/python3.10/dist-packages (from torch->-r requirements.txt (line 4)) (1.11.1)
# Requirement already satisfied: networkx in /usr/local/lib/python3.10/dist-packages (from torch->-r requirements.txt (line 4)) (3.1)
# Requirement already satisfied: jinja2 in /usr/local/lib/python3.10/dist-packages (from torch->-r requirements.txt (line 4)) (3.1.2)
# Requirement already satisfied: triton==2.0.0 in /usr/local/lib/python3.10/dist-packages (from torch->-r requirements.txt (line 4)) (2.0.0)
# Requirement already satisfied: cmake in /usr/local/lib/python3.10/dist-packages (from triton==2.0.0->torch->-r requirements.txt (line 4)) (3.25.2)
# Requirement already satisfied: lit in /usr/local/lib/python3.10/dist-packages (from triton==2.0.0->torch->-r requirements.txt (line 4)) (16.0.5)
# Requirement already satisfied: pillow!=8.3.*,>=5.3.0 in /usr/local/lib/python3.10/dist-packages (from torchvision->-r requirements.txt (line 5)) (8.4.0)
# Requirement already satisfied: fsspec in /usr/local/lib/python3.10/dist-packages (from huggingface-hub<1.0,>=0.14.1->transformers->-r requirements.txt (line 3)) (2023.4.0)
# Requirement already satisfied: MarkupSafe>=2.0 in /usr/local/lib/python3.10/dist-packages (from jinja2->torch->-r requirements.txt (line 4)) (2.1.2)
# Requirement already satisfied: urllib3<1.27,>=1.21.1 in /usr/local/lib/python3.10/dist-packages (from requests->transformers->-r requirements.txt (line 3)) (1.26.15)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.10/dist-packages (from requests->transformers->-r requirements.txt (line 3)) (2022.12.7)
# Requirement already satisfied: charset-normalizer~=2.0.0 in /usr/local/lib/python3.10/dist-packages (from requests->transformers->-r requirements.txt (line 3)) (2.0.12)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.10/dist-packages (from requests->transformers->-r requirements.txt (line 3)) (3.4)
# Requirement already satisfied: mpmath>=0.19 in /usr/local/lib/python3.10/dist-packages (from sympy->torch->-r requirements.txt (line 4)) (1.3.0)
# Installing collected packages: tokenizers, colorlog, huggingface-hub, transformers
# Successfully installed colorlog-6.7.0 huggingface-hub-0.14.1 tokenizers-0.13.3 transformers-4.29.2

# %%
# @title Import
import os
print(os.getcwd())
import sys

from utils import create_logger,set_seed

import time
import argparse
import json
from PIL import Image
import torch

from clip.clip import CLIP
from gen_utils import generate_caption
from gen_utils_no_clip import generate_caption_no_clip
from transformers import AutoModelForMaskedLM, AutoTokenizer
# Out:
# /content/VZIC

# %%
# @title Define parameters
def get_args():
    parser = argparse.ArgumentParser()

    parser.add_argument("--seed", type=int, default=42)
    parser.add_argument("--batch_size", type=int, default=1, help = "Only supports batch_size=1 currently.")
    parser.add_argument("--device", type=str,
                        default='cuda',choices=['cuda','cpu'])

    ## Generation and Controllable Type
    parser.add_argument('--run_type',
                        default='caption',
                        nargs='?',
                        choices=['caption', 'controllable'])
    parser.add_argument('--prompt',
                        default='image of ',type=str)
    parser.add_argument('--order',
                        default='shuffle',
                        nargs='?',
                        choices=['sequential', 'shuffle', 'span', 'random','parallel'],
                        help="Generation order of text")
    parser.add_argument('--control_type',
                        default='sentiment',
                        nargs='?',
                        choices=["sentiment","pos"],
                        help="which controllable task to conduct")
    parser.add_argument('--pos_type', type=list,
                        default=[['DET'], ['ADJ','NOUN'], ['NOUN'],
                                 ['VERB'], ['VERB'],['ADV'], ['ADP'],
                                 ['DET','NOUN'], ['NOUN'], ['NOUN','.'],
                                 ['.','NOUN'],['.','NOUN']],
                        help="predefined part-of-speech templete")
    parser.add_argument('--sentiment_type',
                        default="positive",
                        nargs='?',
                        choices=["positive", "negative"])
    parser.add_argument('--samples_num',
                        default=2,type=int)

    ## Hyperparameters
    parser.add_argument("--sentence_len", type=int, default=10)
    parser.add_argument("--candidate_k", type=int, default=200)
    parser.add_argument("--alpha", type=float, default=0.02, help="weight for fluency")
    parser.add_argument("--beta", type=float, default=2.0, help="weight for image-matching degree")
    parser.add_argument("--gamma", type=float, default=5.0, help="weight for controllable degree")
    parser.add_argument("--lm_temperature", type=float, default=0.1)
    parser.add_argument("--num_iterations", type=int, default=10, help="predefined iterations for Gibbs Sampling")

    ## Models and Paths
    parser.add_argument("--lm_model", type=str, default='bert-base-uncased',
                        help="Path to language model") # bert,roberta
    parser.add_argument("--match_model", type=str, default='openai/clip-vit-base-patch32',
                        help="Path to Image-Text model")  # clip,align
    parser.add_argument("--caption_img_path", type=str, default='./examples/girl.jpg',
                        help="file path of the image for captioning")
    parser.add_argument("--stop_words_path", type=str, default='stop_words.txt',
                        help="Path to stop_words.txt")
    parser.add_argument("--add_extra_stopwords", type=list, default=[],
                        help="you can add some extra stop words")

    args = parser.parse_args(args=[])
    return args

# %%
# @title Image captioning
def run_caption(args, image_path, lm_model, lm_tokenizer, clip, token_mask, logger, model_type):
    FinalCaptionList = []
    BestCaptionList = []
    logger.info(f"Processing: {image_path}")
    image_instance = Image.open(image_path).convert("RGB")
    # img_name = [image_path.spilt("/")[-1]]
    for sample_id in range(args.samples_num):
        logger.info(f"Sample {sample_id}: ")
        gen_texts, clip_scores = generate_caption(image_path, model_type,lm_model, clip, lm_tokenizer, image_instance, token_mask, logger,
                                  prompt=args.prompt, batch_size=args.batch_size, max_len=args.sentence_len,
                                  top_k=args.candidate_k, temperature=args.lm_temperature,
                                  max_iter=args.num_iterations,alpha=args.alpha,beta=args.beta,
                                  generate_order = args.order)
        FinalCaptionStr = "Sample {}: ".format(sample_id + 1) + gen_texts[-2][0]
        BestCaptionStr = "Sample {}: ".format(sample_id + 1) + gen_texts[-1][0]
        FinalCaptionList.append(FinalCaptionStr)
        BestCaptionList.append(BestCaptionStr)
    return FinalCaptionList, BestCaptionList

# %%
# @title GPU/CPU
is_gpu = True #@param {type:"boolean"}

# %% [markdown]
# *   RunType: Select RunType equal to "contrallable" to control text generation.
# *   ControlType: Control text by sentiment or part of speech.
# *   SentimentType: Control sentiment: positive or negative
# *   Order: Generation order of text
# *   Alpha: Weight for fluency; Choose between 0 and 1
# *   Beta: Weight for image-matching degree; Choose between 1 and 5
# *   Gamma: Weight for controllable degree; Choose between 1 and 10
# *   SampleNum: Number of runs; Choose between 1 and 5
# *   Length: Sentence length; Choose between 5 and 10
# *   NumIterations: Iterations for Gibbs Sampling; Choose between 1 and 15

# %%
# @title Select types and parameters
args = get_args()

RunType = 'caption' # @param ['caption', 'controllable']
ControlType = 'sentiment' # @param ["sentiment","pos"]
SentimentType = 'positive' # @param ["positive", "negative"]
Order = 'sequential' # @param ['sequential', 'shuffle', 'random']
Alpha = 0.5 #@param {type:"slider", min:0, max:1, step:0.01}
Beta = 2 # @param {type:"slider", min:0, max:5, step:0.5}
Gamma = 0 # @param {type:"slider", min:0, max:10, step:0.5}
SamplesNum = 1 # @param {type:"slider", min:1, max:5, step:1}
Length = 9 # @param {type:"slider", min:5, max:15,  step:1}
NumIterations = 20 # @param {type:"slider", min:1, max:40, step:1}

args.sentence_len = Length
args.run_type = RunType
args.control_type = ControlType
args.sentiment_type = SentimentType
args.alpha = Alpha
args.beta = Beta
args.gamma = Gamma
args.samples_num = SamplesNum
args.order = Order
args.num_iterations = NumIterations 
args.device = "cuda" if is_gpu else "cpu" 
set_seed(args.seed)

# %%
# @title Create logger

run_type = "caption" if args.run_type=="caption" else args.control_type
if run_type=="sentiment":
    run_type = args.sentiment_type

if os.path.exists("logger")== False:
    os.mkdir("logger")
logger = create_logger(
    "logger",'demo_{}_{}_len{}_topk{}_alpha{}_beta{}_gamma{}_lmtemp{}_{}.log'.format(
    run_type, args.order, args.sentence_len,
    args.candidate_k, args.alpha, args.beta,args.gamma, args.lm_temperature,
    time.strftime("%Y-%m-%d-%H-%M-%S", time.localtime())))

logger.info(f"Generating order:{args.order}")
logger.info(f"Run type:{run_type}")
logger.info(args)
# Out:
# Generating order:sequential
# INFO:ConZIC:Generating order:sequential
# Run type:caption
# INFO:ConZIC:Run type:caption
# Namespace(seed=42, batch_size=1, device='cuda', run_type='caption', prompt='image of ', order='sequential', control_type='sentiment', pos_type=[['DET'], ['ADJ', 'NOUN'], ['NOUN'], ['VERB'], ['VERB'], ['ADV'], ['ADP'], ['DET', 'NOUN'], ['NOUN'], ['NOUN', '.'], ['.', 'NOUN'], ['.', 'NOUN']], sentiment_type='positive', samples_num=1, sentence_len=9, candidate_k=200, alpha=0.5, beta=2, gamma=0, lm_temperature=0.1, num_iterations=20, lm_model='bert-base-uncased', match_model='openai/clip-vit-base-patch32', caption_img_path='./examples/girl.jpg', stop_words_path='stop_words.txt', add_extra_stopwords=[])
# INFO:ConZIC:Namespace(seed=42, batch_size=1, device='cuda', run_type='caption', prompt='image of ', order='sequential', control_type='sentiment', pos_type=[['DET'], ['ADJ', 'NOUN'], ['NOUN'], ['VERB'], ['VERB'], ['ADV'], ['ADP'], ['DET', 'NOUN'], ['NOUN'], ['NOUN', '.'], ['.', 'NOUN'], ['.', 'NOUN']], sentiment_type='positive', samples_num=1, sentence_len=9, candidate_k=200, alpha=0.5, beta=2, gamma=0, lm_temperature=0.1, num_iterations=20, lm_model='bert-base-uncased', match_model='openai/clip-vit-base-patch32', caption_img_path='./examples/girl.jpg', stop_words_path='stop_words.txt', add_extra_stopwords=[])

# %%
torch.cuda.empty_cache()

# %%
from transformers import ViltProcessor, ViltForMaskedLM, AutoModelForMaskedLM, AutoTokenizer
import requests
from PIL import Image
import re
import torch

# @title Load pre-trained model (weights)
multimodal_model = ViltForMaskedLM.from_pretrained("dandelin/vilt-b32-mlm")
multimodal_processor = ViltProcessor.from_pretrained("dandelin/vilt-b32-mlm")
multimodal_model.eval()
multimodal_model = multimodal_model.to(args.device)

# lm_model = AutoModelForMaskedLM.from_pretrained('roberta-large')
# lm_tokenizer = AutoTokenizer.from_pretrained('roberta-large',use_fast=True)
# lm_model.eval()
# lm_model = lm_model.to(args.device)

clip = CLIP(args.match_model)
clip.eval()
clip = clip.to(args.device)
# Out:
# DEBUG:urllib3.connectionpool:Starting new HTTPS connection (1): huggingface.co:443
# DEBUG:urllib3.connectionpool:https://huggingface.co:443 "HEAD /dandelin/vilt-b32-mlm/resolve/main/config.json HTTP/1.1" 200 0
# DEBUG:filelock:Attempting to acquire lock 140051674984656 on /root/.cache/huggingface/hub/models--dandelin--vilt-b32-mlm/blobs/0ae8a07720a54724ebd28ab5837bd55643aab9fa.lock
# DEBUG:filelock:Lock 140051674984656 acquired on /root/.cache/huggingface/hub/models--dandelin--vilt-b32-mlm/blobs/0ae8a07720a54724ebd28ab5837bd55643aab9fa.lock
# DEBUG:urllib3.connectionpool:https://huggingface.co:443 "GET /dandelin/vilt-b32-mlm/resolve/main/config.json HTTP/1.1" 200 653
# Downloading (…)lve/main/config.json:   0%|          | 0.00/653 [00:00<?, ?B/s]
# DEBUG:filelock:Attempting to release lock 140051674984656 on /root/.cache/huggingface/hub/models--dandelin--vilt-b32-mlm/blobs/0ae8a07720a54724ebd28ab5837bd55643aab9fa.lock
# DEBUG:filelock:Lock 140051674984656 released on /root/.cache/huggingface/hub/models--dandelin--vilt-b32-mlm/blobs/0ae8a07720a54724ebd28ab5837bd55643aab9fa.lock
# DEBUG:urllib3.connectionpool:https://huggingface.co:443 "HEAD /dandelin/vilt-b32-mlm/resolve/main/pytorch_model.bin HTTP/1.1" 302 0
# DEBUG:filelock:Attempting to acquire lock 140052029994896 on /root/.cache/huggingface/hub/models--dandelin--vilt-b32-mlm/blobs/e9437103e694deabdba02cbb9220caa184b82f21b956ca837a08e9d5015dff40.lock
# DEBUG:filelock:Lock 140052029994896 acquired on /root/.cache/huggingface/hub/models--dandelin--vilt-b32-mlm/blobs/e9437103e694deabdba02cbb9220caa184b82f21b956ca837a08e9d5015dff40.lock
# DEBUG:urllib3.connectionpool:Starting new HTTPS connection (1): cdn-lfs.huggingface.co:443
# DEBUG:urllib3.connectionpool:https://cdn-lfs.huggingface.co:443 "GET /dandelin/vilt-b32-mlm/e9437103e694deabdba02cbb9220caa184b82f21b956ca837a08e9d5015dff40?response-content-disposition=attachment%3B+filename*%3DUTF-8%27%27pytorch_model.bin%3B+filename%3D%22pytorch_model.bin%22%3B&response-content-type=application%2Foctet-stream&Expires=1685520872&Policy=&Signature=kxKGjbRzLasHtPtPxIG3~MvJNMij2i-9f8TrVyCkc4Q7VPFucqpO0xyVwpjQaxckAmVBy4o40G7ZjKu-FwABKWbKsqW3GwLOHyGjepDQYDS9FSO8i28LRT7NnK3-nvuz5Suul5f3at81ZHGPQkXmd9k4CpnTciMobF7ZFXibL4xxxua5izdDXOSjD5gtBWaqe0FDFzlm79xBXYQr0CyyHmSdjlK5sUlvBKlFBmnX9LuXCBwg-lX33dWHiw45EwOTSB~UBW8kYxSjSxR9SL1An7cSMmvJfwQUakHu1eDCAXHseCd7aC9Ns~hgw~fzRQSNrYIP6TlTf8ZhX85Re8ZngQ__&Key-Pair-Id=KVTP0A1DKRTAX HTTP/1.1" 200 542716055
# Downloading pytorch_model.bin:   0%|          | 0.00/543M [00:00<?, ?B/s]
# DEBUG:filelock:Attempting to release lock 140052029994896 on /root/.cache/huggingface/hub/models--dandelin--vilt-b32-mlm/blobs/e9437103e694deabdba02cbb9220caa184b82f21b956ca837a08e9d5015dff40.lock
# DEBUG:filelock:Lock 140052029994896 released on /root/.cache/huggingface/hub/models--dandelin--vilt-b32-mlm/blobs/e9437103e694deabdba02cbb9220caa184b82f21b956ca837a08e9d5015dff40.lock
# DEBUG:tensorflow:Falling back to TensorFlow client; we recommended you install the Cloud TPU client directly with pip install cloud-tpu-client.
# DEBUG:h5py._conv:Creating converter from 7 to 5
# DEBUG:h5py._conv:Creating converter from 5 to 7
# DEBUG:h5py._conv:Creating converter from 7 to 5
# DEBUG:h5py._conv:Creating converter from 5 to 7
# INFO:numexpr.utils:NumExpr defaulting to 2 threads.
# DEBUG:urllib3.connectionpool:https://huggingface.co:443 "HEAD /dandelin/vilt-b32-mlm/resolve/main/preprocessor_config.json HTTP/1.1" 200 0
# DEBUG:filelock:Attempting to acquire lock 140051675846432 on /root/.cache/huggingface/hub/models--dandelin--vilt-b32-mlm/blobs/4742d0484ad487ca91e7df814a7c079cb8fc3261.lock
# DEBUG:filelock:Lock 140051675846432 acquired on /root/.cache/huggingface/hub/models--dandelin--vilt-b32-mlm/blobs/4742d0484ad487ca91e7df814a7c079cb8fc3261.lock
# DEBUG:urllib3.connectionpool:https://huggingface.co:443 "GET /dandelin/vilt-b32-mlm/resolve/main/preprocessor_config.json HTTP/1.1" 200 251
# Downloading (…)rocessor_config.json:   0%|          | 0.00/251 [00:00<?, ?B/s]
# DEBUG:filelock:Attempting to release lock 140051675846432 on /root/.cache/huggingface/hub/models--dandelin--vilt-b32-mlm/blobs/4742d0484ad487ca91e7df814a7c079cb8fc3261.lock
# DEBUG:filelock:Lock 140051675846432 released on /root/.cache/huggingface/hub/models--dandelin--vilt-b32-mlm/blobs/4742d0484ad487ca91e7df814a7c079cb8fc3261.lock
# DEBUG:urllib3.connectionpool:https://huggingface.co:443 "HEAD /dandelin/vilt-b32-mlm/resolve/main/tokenizer_config.json HTTP/1.1" 200 0
# DEBUG:filelock:Attempting to acquire lock 140050294695984 on /root/.cache/huggingface/hub/models--dandelin--vilt-b32-mlm/blobs/311bbad5faf9a7d5941d8fa183c26afee98e38bc.lock
# DEBUG:filelock:Lock 140050294695984 acquired on /root/.cache/huggingface/hub/models--dandelin--vilt-b32-mlm/blobs/311bbad5faf9a7d5941d8fa183c26afee98e38bc.lock
# DEBUG:urllib3.connectionpool:https://huggingface.co:443 "GET /dandelin/vilt-b32-mlm/resolve/main/tokenizer_config.json HTTP/1.1" 200 320
# Downloading (…)okenizer_config.json:   0%|          | 0.00/320 [00:00<?, ?B/s]
# DEBUG:filelock:Attempting to release lock 140050294695984 on /root/.cache/huggingface/hub/models--dandelin--vilt-b32-mlm/blobs/311bbad5faf9a7d5941d8fa183c26afee98e38bc.lock
# DEBUG:filelock:Lock 140050294695984 released on /root/.cache/huggingface/hub/models--dandelin--vilt-b32-mlm/blobs/311bbad5faf9a7d5941d8fa183c26afee98e38bc.lock
# DEBUG:urllib3.connectionpool:https://huggingface.co:443 "HEAD /dandelin/vilt-b32-mlm/resolve/main/vocab.txt HTTP/1.1" 200 0
# DEBUG:filelock:Attempting to acquire lock 140050154076480 on /root/.cache/huggingface/hub/models--dandelin--vilt-b32-mlm/blobs/fb140275c155a9c7c5a3b3e0e77a9e839594a938.lock
# DEBUG:filelock:Lock 140050154076480 acquired on /root/.cache/huggingface/hub/models--dandelin--vilt-b32-mlm/blobs/fb140275c155a9c7c5a3b3e0e77a9e839594a938.lock
# DEBUG:urllib3.connectionpool:https://huggingface.co:443 "GET /dandelin/vilt-b32-mlm/resolve/main/vocab.txt HTTP/1.1" 200 231508
# Downloading (…)solve/main/vocab.txt:   0%|          | 0.00/232k [00:00<?, ?B/s]
# DEBUG:filelock:Attempting to release lock 140050154076480 on /root/.cache/huggingface/hub/models--dandelin--vilt-b32-mlm/blobs/fb140275c155a9c7c5a3b3e0e77a9e839594a938.lock
# DEBUG:filelock:Lock 140050154076480 released on /root/.cache/huggingface/hub/models--dandelin--vilt-b32-mlm/blobs/fb140275c155a9c7c5a3b3e0e77a9e839594a938.lock
# DEBUG:urllib3.connectionpool:https://huggingface.co:443 "HEAD /dandelin/vilt-b32-mlm/resolve/main/tokenizer.json HTTP/1.1" 200 0
# DEBUG:filelock:Attempting to acquire lock 140050154077536 on /root/.cache/huggingface/hub/models--dandelin--vilt-b32-mlm/blobs/40c4a0f6c414c8218190234bbce9bf4cc04fa3ac.lock
# DEBUG:filelock:Lock 140050154077536 acquired on /root/.cache/huggingface/hub/models--dandelin--vilt-b32-mlm/blobs/40c4a0f6c414c8218190234bbce9bf4cc04fa3ac.lock
# DEBUG:urllib3.connectionpool:https://huggingface.co:443 "GET /dandelin/vilt-b32-mlm/resolve/main/tokenizer.json HTTP/1.1" 200 466081
# Downloading (…)/main/tokenizer.json:   0%|          | 0.00/466k [00:00<?, ?B/s]
# DEBUG:filelock:Attempting to release lock 140050154077536 on /root/.cache/huggingface/hub/models--dandelin--vilt-b32-mlm/blobs/40c4a0f6c414c8218190234bbce9bf4cc04fa3ac.lock
# DEBUG:filelock:Lock 140050154077536 released on /root/.cache/huggingface/hub/models--dandelin--vilt-b32-mlm/blobs/40c4a0f6c414c8218190234bbce9bf4cc04fa3ac.lock
# DEBUG:urllib3.connectionpool:https://huggingface.co:443 "HEAD /dandelin/vilt-b32-mlm/resolve/main/added_tokens.json HTTP/1.1" 404 0
# DEBUG:urllib3.connectionpool:https://huggingface.co:443 "HEAD /dandelin/vilt-b32-mlm/resolve/main/special_tokens_map.json HTTP/1.1" 200 0
# DEBUG:filelock:Attempting to acquire lock 140050154073264 on /root/.cache/huggingface/hub/models--dandelin--vilt-b32-mlm/blobs/e7b0375001f109a6b8873d756ad4f7bbb15fbaa5.lock
# DEBUG:filelock:Lock 140050154073264 acquired on /root/.cache/huggingface/hub/models--dandelin--vilt-b32-mlm/blobs/e7b0375001f109a6b8873d756ad4f7bbb15fbaa5.lock
# DEBUG:urllib3.connectionpool:https://huggingface.co:443 "GET /dandelin/vilt-b32-mlm/resolve/main/special_tokens_map.json HTTP/1.1" 200 112
# Downloading (…)cial_tokens_map.json:   0%|          | 0.00/112 [00:00<?, ?B/s]
# DEBUG:filelock:Attempting to release lock 140050154073264 on /root/.cache/huggingface/hub/models--dandelin--vilt-b32-mlm/blobs/e7b0375001f109a6b8873d756ad4f7bbb15fbaa5.lock
# DEBUG:filelock:Lock 140050154073264 released on /root/.cache/huggingface/hub/models--dandelin--vilt-b32-mlm/blobs/e7b0375001f109a6b8873d756ad4f7bbb15fbaa5.lock
# DEBUG:urllib3.connectionpool:https://huggingface.co:443 "HEAD /openai/clip-vit-base-patch32/resolve/main/config.json HTTP/1.1" 200 0
# DEBUG:filelock:Attempting to acquire lock 140050154486848 on /root/.cache/huggingface/hub/models--openai--clip-vit-base-patch32/blobs/a2a88b96561196777ca173b15309ea859f4d2ce0.lock
# DEBUG:filelock:Lock 140050154486848 acquired on /root/.cache/huggingface/hub/models--openai--clip-vit-base-patch32/blobs/a2a88b96561196777ca173b15309ea859f4d2ce0.lock
# DEBUG:urllib3.connectionpool:https://huggingface.co:443 "GET /openai/clip-vit-base-patch32/resolve/main/config.json HTTP/1.1" 200 4186
# Initializing CLIP model...
# Downloading (…)lve/main/config.json:   0%|          | 0.00/4.19k [00:00<?, ?B/s]
# DEBUG:filelock:Attempting to release lock 140050154486848 on /root/.cache/huggingface/hub/models--openai--clip-vit-base-patch32/blobs/a2a88b96561196777ca173b15309ea859f4d2ce0.lock
# DEBUG:filelock:Lock 140050154486848 released on /root/.cache/huggingface/hub/models--openai--clip-vit-base-patch32/blobs/a2a88b96561196777ca173b15309ea859f4d2ce0.lock
# DEBUG:urllib3.connectionpool:https://huggingface.co:443 "HEAD /openai/clip-vit-base-patch32/resolve/main/pytorch_model.bin HTTP/1.1" 302 0
# DEBUG:filelock:Attempting to acquire lock 140050154071728 on /root/.cache/huggingface/hub/models--openai--clip-vit-base-patch32/blobs/a63082132ba4f97a80bea76823f544493bffa8082296d62d71581a4feff1576f.lock
# DEBUG:filelock:Lock 140050154071728 acquired on /root/.cache/huggingface/hub/models--openai--clip-vit-base-patch32/blobs/a63082132ba4f97a80bea76823f544493bffa8082296d62d71581a4feff1576f.lock
# DEBUG:urllib3.connectionpool:https://cdn-lfs.huggingface.co:443 "GET /openai/clip-vit-base-patch32/a63082132ba4f97a80bea76823f544493bffa8082296d62d71581a4feff1576f?response-content-disposition=attachment%3B+filename*%3DUTF-8%27%27pytorch_model.bin%3B+filename%3D%22pytorch_model.bin%22%3B&response-content-type=application%2Foctet-stream&Expires=1685518901&Policy=__&Signature=S2SZfZUfQhPClExrnmWcjNIrbk99rOfJN~MQZr-vzH6ZiWzKxamU5hv9yHKgQYvjoy3tBlYQYV~-frxpkGBZhKQK2voTlwe~XDoRv4kVIR62kNG6zu6fESTN02S7xuK2La362X3PDR9mahzjjP5jbRqSeGnREOdS731bPjjLjKsRjcyWp-aKGH4ATSjhJsn6K7c3h8DKQ9u~M9S5nrfEvhdUamyEwmgobH3~UGeroUgALttbJyFE8ZVZCapCbmHTXYmH43eRSE3qZtnsDsaXbc40OIYu6QqSDFkasi-bFOtvSlIcNVgQw6bpRu2HCCert8lX5G1pECB5bgYmtZDHsg__&Key-Pair-Id=KVTP0A1DKRTAX HTTP/1.1" 200 605247071
# Downloading pytorch_model.bin:   0%|          | 0.00/605M [00:00<?, ?B/s]
# DEBUG:filelock:Attempting to release lock 140050154071728 on /root/.cache/huggingface/hub/models--openai--clip-vit-base-patch32/blobs/a63082132ba4f97a80bea76823f544493bffa8082296d62d71581a4feff1576f.lock
# DEBUG:filelock:Lock 140050154071728 released on /root/.cache/huggingface/hub/models--openai--clip-vit-base-patch32/blobs/a63082132ba4f97a80bea76823f544493bffa8082296d62d71581a4feff1576f.lock
# DEBUG:urllib3.connectionpool:https://huggingface.co:443 "HEAD /openai/clip-vit-base-patch32/resolve/main/preprocessor_config.json HTTP/1.1" 200 0
# DEBUG:filelock:Attempting to acquire lock 140051474497104 on /root/.cache/huggingface/hub/models--openai--clip-vit-base-patch32/blobs/5a12a1eb250987a4eee0e3e7d7338c4b22724be1.lock
# DEBUG:filelock:Lock 140051474497104 acquired on /root/.cache/huggingface/hub/models--openai--clip-vit-base-patch32/blobs/5a12a1eb250987a4eee0e3e7d7338c4b22724be1.lock
# DEBUG:urllib3.connectionpool:https://huggingface.co:443 "GET /openai/clip-vit-base-patch32/resolve/main/preprocessor_config.json HTTP/1.1" 200 316
# Downloading (…)rocessor_config.json:   0%|          | 0.00/316 [00:00<?, ?B/s]
# DEBUG:filelock:Attempting to release lock 140051474497104 on /root/.cache/huggingface/hub/models--openai--clip-vit-base-patch32/blobs/5a12a1eb250987a4eee0e3e7d7338c4b22724be1.lock
# DEBUG:filelock:Lock 140051474497104 released on /root/.cache/huggingface/hub/models--openai--clip-vit-base-patch32/blobs/5a12a1eb250987a4eee0e3e7d7338c4b22724be1.lock
# DEBUG:urllib3.connectionpool:https://huggingface.co:443 "HEAD /openai/clip-vit-base-patch32/resolve/main/tokenizer_config.json HTTP/1.1" 200 0
# DEBUG:filelock:Attempting to acquire lock 140050154077872 on /root/.cache/huggingface/hub/models--openai--clip-vit-base-patch32/blobs/ab0ca294e9ef2a950015496bc13b84e1bb462b09.lock
# DEBUG:filelock:Lock 140050154077872 acquired on /root/.cache/huggingface/hub/models--openai--clip-vit-base-patch32/blobs/ab0ca294e9ef2a950015496bc13b84e1bb462b09.lock
# DEBUG:urllib3.connectionpool:https://huggingface.co:443 "GET /openai/clip-vit-base-patch32/resolve/main/tokenizer_config.json HTTP/1.1" 200 568
# Downloading (…)okenizer_config.json:   0%|          | 0.00/568 [00:00<?, ?B/s]
# DEBUG:filelock:Attempting to release lock 140050154077872 on /root/.cache/huggingface/hub/models--openai--clip-vit-base-patch32/blobs/ab0ca294e9ef2a950015496bc13b84e1bb462b09.lock
# DEBUG:filelock:Lock 140050154077872 released on /root/.cache/huggingface/hub/models--openai--clip-vit-base-patch32/blobs/ab0ca294e9ef2a950015496bc13b84e1bb462b09.lock
# DEBUG:urllib3.connectionpool:https://huggingface.co:443 "HEAD /openai/clip-vit-base-patch32/resolve/main/vocab.json HTTP/1.1" 200 0
# DEBUG:filelock:Attempting to acquire lock 140050154800080 on /root/.cache/huggingface/hub/models--openai--clip-vit-base-patch32/blobs/182766ce89b439768edadda342519f33802f5364.lock
# DEBUG:filelock:Lock 140050154800080 acquired on /root/.cache/huggingface/hub/models--openai--clip-vit-base-patch32/blobs/182766ce89b439768edadda342519f33802f5364.lock
# DEBUG:urllib3.connectionpool:https://huggingface.co:443 "GET /openai/clip-vit-base-patch32/resolve/main/vocab.json HTTP/1.1" 200 862328
# Downloading (…)olve/main/vocab.json:   0%|          | 0.00/862k [00:00<?, ?B/s]
# DEBUG:filelock:Attempting to release lock 140050154800080 on /root/.cache/huggingface/hub/models--openai--clip-vit-base-patch32/blobs/182766ce89b439768edadda342519f33802f5364.lock
# DEBUG:filelock:Lock 140050154800080 released on /root/.cache/huggingface/hub/models--openai--clip-vit-base-patch32/blobs/182766ce89b439768edadda342519f33802f5364.lock
# DEBUG:urllib3.connectionpool:https://huggingface.co:443 "HEAD /openai/clip-vit-base-patch32/resolve/main/merges.txt HTTP/1.1" 200 0
# DEBUG:filelock:Attempting to acquire lock 140050154813040 on /root/.cache/huggingface/hub/models--openai--clip-vit-base-patch32/blobs/bbfec752c9a675946c6dce106def6f35c882dcc2.lock
# DEBUG:filelock:Lock 140050154813040 acquired on /root/.cache/huggingface/hub/models--openai--clip-vit-base-patch32/blobs/bbfec752c9a675946c6dce106def6f35c882dcc2.lock
# DEBUG:urllib3.connectionpool:https://huggingface.co:443 "GET /openai/clip-vit-base-patch32/resolve/main/merges.txt HTTP/1.1" 200 524657
# Downloading (…)olve/main/merges.txt:   0%|          | 0.00/525k [00:00<?, ?B/s]
# DEBUG:filelock:Attempting to release lock 140050154813040 on /root/.cache/huggingface/hub/models--openai--clip-vit-base-patch32/blobs/bbfec752c9a675946c6dce106def6f35c882dcc2.lock
# DEBUG:filelock:Lock 140050154813040 released on /root/.cache/huggingface/hub/models--openai--clip-vit-base-patch32/blobs/bbfec752c9a675946c6dce106def6f35c882dcc2.lock
# DEBUG:urllib3.connectionpool:https://huggingface.co:443 "HEAD /openai/clip-vit-base-patch32/resolve/main/tokenizer.json HTTP/1.1" 200 0
# DEBUG:filelock:Attempting to acquire lock 140050154801424 on /root/.cache/huggingface/hub/models--openai--clip-vit-base-patch32/blobs/564c0ebd5ce29c4ee4864004aee693deadd3128c.lock
# DEBUG:filelock:Lock 140050154801424 acquired on /root/.cache/huggingface/hub/models--openai--clip-vit-base-patch32/blobs/564c0ebd5ce29c4ee4864004aee693deadd3128c.lock
# DEBUG:urllib3.connectionpool:https://huggingface.co:443 "GET /openai/clip-vit-base-patch32/resolve/main/tokenizer.json HTTP/1.1" 200 2224041
# Downloading (…)/main/tokenizer.json:   0%|          | 0.00/2.22M [00:00<?, ?B/s]
# DEBUG:filelock:Attempting to release lock 140050154801424 on /root/.cache/huggingface/hub/models--openai--clip-vit-base-patch32/blobs/564c0ebd5ce29c4ee4864004aee693deadd3128c.lock
# DEBUG:filelock:Lock 140050154801424 released on /root/.cache/huggingface/hub/models--openai--clip-vit-base-patch32/blobs/564c0ebd5ce29c4ee4864004aee693deadd3128c.lock
# DEBUG:urllib3.connectionpool:https://huggingface.co:443 "HEAD /openai/clip-vit-base-patch32/resolve/main/added_tokens.json HTTP/1.1" 404 0
# DEBUG:urllib3.connectionpool:https://huggingface.co:443 "HEAD /openai/clip-vit-base-patch32/resolve/main/special_tokens_map.json HTTP/1.1" 200 0
# DEBUG:filelock:Attempting to acquire lock 140051474369024 on /root/.cache/huggingface/hub/models--openai--clip-vit-base-patch32/blobs/9bfb42aa97dcd61e89f279ccaee988bccb4fabae.lock
# DEBUG:filelock:Lock 140051474369024 acquired on /root/.cache/huggingface/hub/models--openai--clip-vit-base-patch32/blobs/9bfb42aa97dcd61e89f279ccaee988bccb4fabae.lock
# DEBUG:urllib3.connectionpool:https://huggingface.co:443 "GET /openai/clip-vit-base-patch32/resolve/main/special_tokens_map.json HTTP/1.1" 200 389
# Downloading (…)cial_tokens_map.json:   0%|          | 0.00/389 [00:00<?, ?B/s]
# DEBUG:filelock:Attempting to release lock 140051474369024 on /root/.cache/huggingface/hub/models--openai--clip-vit-base-patch32/blobs/9bfb42aa97dcd61e89f279ccaee988bccb4fabae.lock
# DEBUG:filelock:Lock 140051474369024 released on /root/.cache/huggingface/hub/models--openai--clip-vit-base-patch32/blobs/9bfb42aa97dcd61e89f279ccaee988bccb4fabae.lock
# DEBUG:urllib3.connectionpool:https://huggingface.co:443 "HEAD /openai/clip-vit-base-patch32/resolve/main/vocab.json HTTP/1.1" 200 0
# CLIP model initialized.

# %%
#@title Remove stop words, token mask
def stopandmask(tokenizer, model_type):
  if model_type == "ViLT":
    tokenizer = tokenizer.tokenizer
  with open(args.stop_words_path,'r',encoding='utf-8') as stop_words_file:
      stop_words = stop_words_file.readlines()
      stop_words_ = [stop_word.rstrip('\n') for stop_word in stop_words]
      stop_words_ += args.add_extra_stopwords
      stop_ids = tokenizer.convert_tokens_to_ids(stop_words_)
      token_mask = torch.ones((1,tokenizer.vocab_size))
      for stop_id in stop_ids:
          token_mask[0,stop_id]=0
      token_mask = token_mask.to(args.device)
  return stop_words, stop_ids, token_mask

# %%
import os
#@title Select examples
example_name = 'horse.png' # @param ['cat.png', 'girl.jpg', 'Gosh.jpeg', 'horse.png'] 
example_img_path = os.path.join(os.getcwd(),"examples", example_name)

# %%
# multimodal_model = ViltForMaskedLM.from_pretrained("dandelin/vilt-b32-mlm")
# multimodal_processor = ViltProcessor.from_pretrained("dandelin/vilt-b32-mlm")
# multimodal_model.eval()
# multimodal_model = multimodal_model.to(args.device)

# %%
lm_model = AutoModelForMaskedLM.from_pretrained('bert-base-uncased')
lm_tokenizer = AutoTokenizer.from_pretrained('bert-base-uncased',use_fast=True)
lm_model.eval()
lm_model = lm_model.to(args.device)
# Out:
# DEBUG:urllib3.connectionpool:https://huggingface.co:443 "HEAD /bert-base-uncased/resolve/main/config.json HTTP/1.1" 200 0
# DEBUG:filelock:Attempting to acquire lock 140052029994704 on /root/.cache/huggingface/hub/models--bert-base-uncased/blobs/45a2321a7ecfdaaf60a6c1fd7f5463994cc8907d.lock
# DEBUG:filelock:Lock 140052029994704 acquired on /root/.cache/huggingface/hub/models--bert-base-uncased/blobs/45a2321a7ecfdaaf60a6c1fd7f5463994cc8907d.lock
# DEBUG:urllib3.connectionpool:https://huggingface.co:443 "GET /bert-base-uncased/resolve/main/config.json HTTP/1.1" 200 570
# Downloading (…)lve/main/config.json:   0%|          | 0.00/570 [00:00<?, ?B/s]
# DEBUG:filelock:Attempting to release lock 140052029994704 on /root/.cache/huggingface/hub/models--bert-base-uncased/blobs/45a2321a7ecfdaaf60a6c1fd7f5463994cc8907d.lock
# DEBUG:filelock:Lock 140052029994704 released on /root/.cache/huggingface/hub/models--bert-base-uncased/blobs/45a2321a7ecfdaaf60a6c1fd7f5463994cc8907d.lock
# DEBUG:urllib3.connectionpool:https://huggingface.co:443 "HEAD /bert-base-uncased/resolve/main/pytorch_model.bin HTTP/1.1" 302 0
# DEBUG:filelock:Attempting to acquire lock 140051431946608 on /root/.cache/huggingface/hub/models--bert-base-uncased/blobs/097417381d6c7230bd9e3557456d726de6e83245ec8b24f529f60198a67b203a.lock
# DEBUG:filelock:Lock 140051431946608 acquired on /root/.cache/huggingface/hub/models--bert-base-uncased/blobs/097417381d6c7230bd9e3557456d726de6e83245ec8b24f529f60198a67b203a.lock
# DEBUG:urllib3.connectionpool:https://cdn-lfs.huggingface.co:443 "GET /bert-base-uncased/097417381d6c7230bd9e3557456d726de6e83245ec8b24f529f60198a67b203a?response-content-disposition=attachment%3B+filename*%3DUTF-8%27%27pytorch_model.bin%3B+filename%3D%22pytorch_model.bin%22%3B&response-content-type=application%2Foctet-stream&Expires=1685518776&Policy=eyJTdGF0ZW1lbnQiOlt7IlJlc291cmNlIjoiaHR0cHM6Ly9jZG4tbGZzLmh1Z2dpbmdmYWNlLmNvL2JlcnQtYmFzZS11bmNhc2VkLzA5NzQxNzM4MWQ2YzcyMzBiZDllMzU1NzQ1NmQ3MjZkZTZlODMyNDVlYzhiMjRmNTI5ZjYwMTk4YTY3YjIwM2E~cmVzcG9uc2UtY29udGVudC1kaXNwb3NpdGlvbj0qJnJlc3BvbnNlLWNvbnRlbnQtdHlwZT0qIiwiQ29uZGl0aW9uIjp7IkRhdGVMZXNzVGhhbiI6eyJBV1M6RXBvY2hUaW1lIjoxNjg1NTE4Nzc2fX19XX0_&Signature=r9MJqzyxPszYyS2JoNg1IHVwwCDLsgsC6lCbLZHFxZHZgXWefJhIvWgwHmcf8v59mAq9YlciIEoTQPCdCASgWAiV-PKH2AdkoPanaKTke75jT-Vfv3eRkbwWVovdsy9ycqhKlniBVoHkKLUr59lQ-JIKLOV2WKXCLd0aA7OcRLkJr33VzzriAJl1okhtZccAtgucIHmvBfs1lsgoC2otpyX9iADZgOPM3fJMQnXt2mr7lNF~8Advm~e1xqit0rIA4Pw3koiY9km3yEdc7s9gpHHEvHakxP~tj8A-ZApSmplrWVEhO55x0l~3Ca6nQ8QridR8-abkH7Dtb~u14ApE0A__&Key-Pair-Id=KVTP0A1DKRTAX HTTP/1.1" 200 440473133
# Downloading pytorch_model.bin:   0%|          | 0.00/440M [00:00<?, ?B/s]
# DEBUG:filelock:Attempting to release lock 140051431946608 on /root/.cache/huggingface/hub/models--bert-base-uncased/blobs/097417381d6c7230bd9e3557456d726de6e83245ec8b24f529f60198a67b203a.lock
# DEBUG:filelock:Lock 140051431946608 released on /root/.cache/huggingface/hub/models--bert-base-uncased/blobs/097417381d6c7230bd9e3557456d726de6e83245ec8b24f529f60198a67b203a.lock
# Some weights of the model checkpoint at bert-base-uncased were not used when initializing BertForMaskedLM: ['cls.seq_relationship.weight', 'cls.seq_relationship.bias']
# - This IS expected if you are initializing BertForMaskedLM from the checkpoint of a model trained on another task or with another architecture (e.g. initializing a BertForSequenceClassification model from a BertForPreTraining model).
# - This IS NOT expected if you are initializing BertForMaskedLM from the checkpoint of a model that you expect to be exactly identical (initializing a BertForSequenceClassification model from a BertForSequenceClassification model).
# DEBUG:urllib3.connectionpool:https://huggingface.co:443 "HEAD /bert-base-uncased/resolve/main/generation_config.json HTTP/1.1" 404 0
# DEBUG:urllib3.connectionpool:https://huggingface.co:443 "HEAD /bert-base-uncased/resolve/main/tokenizer_config.json HTTP/1.1" 200 0
# DEBUG:filelock:Attempting to acquire lock 140051474603152 on /root/.cache/huggingface/hub/models--bert-base-uncased/blobs/a661b1a138dac6dc5590367402d100765010ffd6.lock
# DEBUG:filelock:Lock 140051474603152 acquired on /root/.cache/huggingface/hub/models--bert-base-uncased/blobs/a661b1a138dac6dc5590367402d100765010ffd6.lock
# DEBUG:urllib3.connectionpool:https://huggingface.co:443 "GET /bert-base-uncased/resolve/main/tokenizer_config.json HTTP/1.1" 200 28
# Downloading (…)okenizer_config.json:   0%|          | 0.00/28.0 [00:00<?, ?B/s]
# DEBUG:filelock:Attempting to release lock 140051474603152 on /root/.cache/huggingface/hub/models--bert-base-uncased/blobs/a661b1a138dac6dc5590367402d100765010ffd6.lock
# DEBUG:filelock:Lock 140051474603152 released on /root/.cache/huggingface/hub/models--bert-base-uncased/blobs/a661b1a138dac6dc5590367402d100765010ffd6.lock
# DEBUG:urllib3.connectionpool:https://huggingface.co:443 "HEAD /bert-base-uncased/resolve/main/vocab.txt HTTP/1.1" 200 0
# DEBUG:filelock:Attempting to acquire lock 140051432250512 on /root/.cache/huggingface/hub/models--bert-base-uncased/blobs/fb140275c155a9c7c5a3b3e0e77a9e839594a938.lock
# DEBUG:filelock:Lock 140051432250512 acquired on /root/.cache/huggingface/hub/models--bert-base-uncased/blobs/fb140275c155a9c7c5a3b3e0e77a9e839594a938.lock
# DEBUG:urllib3.connectionpool:https://huggingface.co:443 "GET /bert-base-uncased/resolve/main/vocab.txt HTTP/1.1" 200 231508
# Downloading (…)solve/main/vocab.txt:   0%|          | 0.00/232k [00:00<?, ?B/s]
# DEBUG:filelock:Attempting to release lock 140051432250512 on /root/.cache/huggingface/hub/models--bert-base-uncased/blobs/fb140275c155a9c7c5a3b3e0e77a9e839594a938.lock
# DEBUG:filelock:Lock 140051432250512 released on /root/.cache/huggingface/hub/models--bert-base-uncased/blobs/fb140275c155a9c7c5a3b3e0e77a9e839594a938.lock
# DEBUG:urllib3.connectionpool:https://huggingface.co:443 "HEAD /bert-base-uncased/resolve/main/tokenizer.json HTTP/1.1" 200 0
# DEBUG:filelock:Attempting to acquire lock 140051675844464 on /root/.cache/huggingface/hub/models--bert-base-uncased/blobs/949a6f013d67eb8a5b4b5b46026217b888021b88.lock
# DEBUG:filelock:Lock 140051675844464 acquired on /root/.cache/huggingface/hub/models--bert-base-uncased/blobs/949a6f013d67eb8a5b4b5b46026217b888021b88.lock
# DEBUG:urllib3.connectionpool:https://huggingface.co:443 "GET /bert-base-uncased/resolve/main/tokenizer.json HTTP/1.1" 200 466062
# Downloading (…)/main/tokenizer.json:   0%|          | 0.00/466k [00:00<?, ?B/s]
# DEBUG:filelock:Attempting to release lock 140051675844464 on /root/.cache/huggingface/hub/models--bert-base-uncased/blobs/949a6f013d67eb8a5b4b5b46026217b888021b88.lock
# DEBUG:filelock:Lock 140051675844464 released on /root/.cache/huggingface/hub/models--bert-base-uncased/blobs/949a6f013d67eb8a5b4b5b46026217b888021b88.lock
# DEBUG:urllib3.connectionpool:https://huggingface.co:443 "HEAD /bert-base-uncased/resolve/main/added_tokens.json HTTP/1.1" 404 0
# DEBUG:urllib3.connectionpool:https://huggingface.co:443 "HEAD /bert-base-uncased/resolve/main/special_tokens_map.json HTTP/1.1" 404 0

# %%
# @title Run 
import gc
gc.collect()
from gen_utils import generate_caption

model = multimodal_model
processor = multimodal_processor
model_type = "ViLT"

# model = lm_model
# processor = lm_tokenizer
# model_type = "BERT"

args.alpha = 0.05
args.beta = 2
args.candidate_k = 10
args.num_iterations = 30

stop_words, stop_ids, token_mask = stopandmask(processor, model_type)
img_path = example_img_path

FinalCaption, BestCaption = run_caption(args, img_path, model, processor, clip, token_mask, logger, model_type=model_type)
# Out:
# Processing: /content/VZIC/examples/horse.png
# INFO:ConZIC:Processing: /content/VZIC/examples/horse.png
# DEBUG:PIL.PngImagePlugin:STREAM b'IHDR' 16 13
# DEBUG:PIL.PngImagePlugin:STREAM b'IDAT' 41 9332
# Sample 0:
# INFO:ConZIC:Sample 0:
# Cuda is available.
# Device is 0
# iter 1, The 1-th image: / | clip score 0.358: [CLS] image of horse standing opposite of alre vector design. [SEP]
# INFO:ConZIC:iter 1, The 1-th image: / | clip score 0.358: [CLS] image of horse standing opposite of alre vector design. [SEP]
# iter 2, The 1-th image: / | clip score 0.383: [CLS] image of horse standing opposite an other outlined vector drawing style [SEP]
# INFO:ConZIC:iter 2, The 1-th image: / | clip score 0.383: [CLS] image of horse standing opposite an other outlined vector drawing style [SEP]
# iter 3, The 1-th image: / | clip score 0.384: [CLS] image of horse standing opposite the other drawing simple line icon [SEP]
# INFO:ConZIC:iter 3, The 1-th image: / | clip score 0.384: [CLS] image of horse standing opposite the other drawing simple line icon [SEP]
# iter 4, The 1-th image: / | clip score 0.388: [CLS] image of horse standing opposite the other drawing black vector icon [SEP]
# INFO:ConZIC:iter 4, The 1-th image: / | clip score 0.388: [CLS] image of horse standing opposite the other drawing black vector icon [SEP]
# iter 5, The 1-th image: / | clip score 0.387: [CLS] image of horse standing opposite the other line drawing free icon [SEP]
# INFO:ConZIC:iter 5, The 1-th image: / | clip score 0.387: [CLS] image of horse standing opposite the other line drawing free icon [SEP]
# iter 6, The 1-th image: / | clip score 0.392: [CLS] image of horse standing near no solid line drawing free icon [SEP]
# INFO:ConZIC:iter 6, The 1-th image: / | clip score 0.392: [CLS] image of horse standing near no solid line drawing free icon [SEP]
# iter 7, The 1-th image: / | clip score 0.378: [CLS] image of horse standing in no other line drawing stock outline [SEP]
# INFO:ConZIC:iter 7, The 1-th image: / | clip score 0.378: [CLS] image of horse standing in no other line drawing stock outline [SEP]
# iter 8, The 1-th image: / | clip score 0.380: [CLS] image of horse sitting near an empty spot drawn by hand [SEP]
# INFO:ConZIC:iter 8, The 1-th image: / | clip score 0.380: [CLS] image of horse sitting near an empty spot drawn by hand [SEP]
# iter 9, The 1-th image: / | clip score 0.391: [CLS] image of horse sitting in small flat style drawn by person [SEP]
# INFO:ConZIC:iter 9, The 1-th image: / | clip score 0.391: [CLS] image of horse sitting in small flat style drawn by person [SEP]
# iter 10, The 1-th image: / | clip score 0.383: [CLS] image of horse standing in the line style drawn by brush [SEP]
# INFO:ConZIC:iter 10, The 1-th image: / | clip score 0.383: [CLS] image of horse standing in the line style drawn by brush [SEP]
# iter 11, The 1-th image: / | clip score 0.386: [CLS] image of horse standing in all line icon drawn by hand [SEP]
# INFO:ConZIC:iter 11, The 1-th image: / | clip score 0.386: [CLS] image of horse standing in all line icon drawn by hand [SEP]
# iter 12, The 1-th image: / | clip score 0.391: [CLS] image of horse standing with no outline style drawn by person [SEP]
# INFO:ConZIC:iter 12, The 1-th image: / | clip score 0.391: [CLS] image of horse standing with no outline style drawn by person [SEP]
# iter 13, The 1-th image: / | clip score 0.391: [CLS] image of horse standing with no outline style drawn by person [SEP]
# INFO:ConZIC:iter 13, The 1-th image: / | clip score 0.391: [CLS] image of horse standing with no outline style drawn by person [SEP]
# iter 14, The 1-th image: / | clip score 0.391: [CLS] image of horse standing with no outline style drawn by person [SEP]
# INFO:ConZIC:iter 14, The 1-th image: / | clip score 0.391: [CLS] image of horse standing with no outline style drawn by person [SEP]
# iter 15, The 1-th image: / | clip score 0.391: [CLS] image of horse standing with no outline style drawn by person [SEP]
# INFO:ConZIC:iter 15, The 1-th image: / | clip score 0.391: [CLS] image of horse standing with no outline style drawn by person [SEP]
# iter 16, The 1-th image: / | clip score 0.391: [CLS] image of horse standing with no outline style drawn by person [SEP]
# INFO:ConZIC:iter 16, The 1-th image: / | clip score 0.391: [CLS] image of horse standing with no outline style drawn by person [SEP]
# iter 17, The 1-th image: / | clip score 0.391: [CLS] image of horse standing with no outline style drawn by person [SEP]
# INFO:ConZIC:iter 17, The 1-th image: / | clip score 0.391: [CLS] image of horse standing with no outline style drawn by person [SEP]
# iter 18, The 1-th image: / | clip score 0.391: [CLS] image of horse standing with no outline style drawn by person [SEP]
# INFO:ConZIC:iter 18, The 1-th image: / | clip score 0.391: [CLS] image of horse standing with no outline style drawn by person [SEP]
# iter 19, The 1-th image: / | clip score 0.391: [CLS] image of horse standing with no outline style drawn by person [SEP]
# INFO:ConZIC:iter 19, The 1-th image: / | clip score 0.391: [CLS] image of horse standing with no outline style drawn by person [SEP]
# iter 20, The 1-th image: / | clip score 0.391: [CLS] image of horse standing with no outline style drawn by person [SEP]
# INFO:ConZIC:iter 20, The 1-th image: / | clip score 0.391: [CLS] image of horse standing with no outline style drawn by person [SEP]
# iter 21, The 1-th image: / | clip score 0.391: [CLS] image of horse standing with no outline style drawn by person [SEP]
# INFO:ConZIC:iter 21, The 1-th image: / | clip score 0.391: [CLS] image of horse standing with no outline style drawn by person [SEP]
# iter 22, The 1-th image: / | clip score 0.391: [CLS] image of horse standing with no outline style drawn by person [SEP]
# INFO:ConZIC:iter 22, The 1-th image: / | clip score 0.391: [CLS] image of horse standing with no outline style drawn by person [SEP]
# iter 23, The 1-th image: / | clip score 0.391: [CLS] image of horse standing with no outline style drawn by person [SEP]
# INFO:ConZIC:iter 23, The 1-th image: / | clip score 0.391: [CLS] image of horse standing with no outline style drawn by person [SEP]
# iter 24, The 1-th image: / | clip score 0.391: [CLS] image of horse standing with no outline style drawn by person [SEP]
# INFO:ConZIC:iter 24, The 1-th image: / | clip score 0.391: [CLS] image of horse standing with no outline style drawn by person [SEP]
# iter 25, The 1-th image: / | clip score 0.391: [CLS] image of horse standing with no outline style drawn by person [SEP]
# INFO:ConZIC:iter 25, The 1-th image: / | clip score 0.391: [CLS] image of horse standing with no outline style drawn by person [SEP]
# iter 26, The 1-th image: / | clip score 0.391: [CLS] image of horse standing with no outline style drawn by person [SEP]
# INFO:ConZIC:iter 26, The 1-th image: / | clip score 0.391: [CLS] image of horse standing with no outline style drawn by person [SEP]
# iter 27, The 1-th image: / | clip score 0.391: [CLS] image of horse standing with no outline style drawn by person [SEP]
# INFO:ConZIC:iter 27, The 1-th image: / | clip score 0.391: [CLS] image of horse standing with no outline style drawn by person [SEP]
# iter 28, The 1-th image: / | clip score 0.391: [CLS] image of horse standing with no outline style drawn by person [SEP]
# INFO:ConZIC:iter 28, The 1-th image: / | clip score 0.391: [CLS] image of horse standing with no outline style drawn by person [SEP]
# iter 29, The 1-th image: / | clip score 0.391: [CLS] image of horse standing with no outline style drawn by person [SEP]
# INFO:ConZIC:iter 29, The 1-th image: / | clip score 0.391: [CLS] image of horse standing with no outline style drawn by person [SEP]
# iter 30, The 1-th image: / | clip score 0.391: [CLS] image of horse standing with no outline style drawn by person [SEP]
# INFO:ConZIC:iter 30, The 1-th image: / | clip score 0.391: [CLS] image of horse standing with no outline style drawn by person [SEP]
# Finished in 16.084s
# INFO:ConZIC:Finished in 16.084s
# The 1-th image: /
# INFO:ConZIC:The 1-th image: /
# final caption: image of horse standing with no outline style drawn by person
# INFO:ConZIC:final caption: image of horse standing with no outline style drawn by person
# best caption: image of horse standing near no solid line drawing free icon
# INFO:ConZIC:best caption: image of horse standing near no solid line drawing free icon

# %%
# @title Output
Image.open(img_path).show()
print("Final Caption\n")
for i in range(len(FinalCaption)):
    print(f"{FinalCaption[i]}\n")
print("Best Caption\n")
for i in range(len(BestCaption)):
    print(f"{BestCaption[i]}\n")
# Out:
# DEBUG:PIL.PngImagePlugin:STREAM b'IHDR' 16 13
# DEBUG:PIL.PngImagePlugin:STREAM b'IDAT' 41 9332
# <PIL.PngImagePlugin.PngImageFile image mode=RGB size=256x256 at 0x7F6043E0B100>
# Final Caption
#
# Sample 1: image of horse standing with no outline style drawn by person
#
# Best Caption
#
# Sample 1: image of horse standing near no solid line drawing free icon

# %% [markdown]
# ## Ablation Study

# %%
# @title Image captioning without clip score
from gen_utils_no_clip import generate_caption_no_clip

def run_caption_no_clip(args, image_path, lm_model, lm_tokenizer, clip, token_mask, logger, model_type):
    FinalCaptionList_noclip = []
    logger.info(f"Processing: {image_path}")
    image_instance = Image.open(image_path).convert("RGB")
    # img_name = [image_path.spilt("/")[-1]]
    for sample_id in range(args.samples_num):
        logger.info(f"Sample {sample_id}: ")
        gen_texts = generate_caption_no_clip(image_path, model_type,lm_model, clip, lm_tokenizer, image_instance, token_mask, logger,
                                  prompt=args.prompt, batch_size=args.batch_size, max_len=args.sentence_len,
                                  top_k=args.candidate_k, temperature=args.lm_temperature,
                                  max_iter=args.num_iterations,
                                  generate_order = args.order)
        FinalCaptionStr = "Sample {}: ".format(sample_id + 1) + gen_texts[-2][0]
        FinalCaptionList_noclip.append(FinalCaptionStr)
    return FinalCaptionList_noclip

# %%
# @title Run
import gc
gc.collect()

model = multimodal_model
processor = multimodal_processor
model_type = "ViLT"

# model = lm_model
# processor = lm_tokenizer
# model_type = "BERT"

args.candidate_k = 10
args.num_iterations = 30

stop_words, stop_ids, token_mask = stopandmask(processor, model_type)
img_path = example_img_path

FinalCaption_noclip = run_caption_no_clip(args, img_path, model, processor, clip, token_mask, logger, model_type=model_type)
# Out:
# Processing: /content/VZIC/examples/horse.png
# INFO:ConZIC:Processing: /content/VZIC/examples/horse.png
# DEBUG:PIL.PngImagePlugin:STREAM b'IHDR' 16 13
# DEBUG:PIL.PngImagePlugin:STREAM b'IDAT' 41 9332
# Sample 0:
# INFO:ConZIC:Sample 0:
# iter 1, The 1-th image: / | [CLS] image of a horse with a grungy pattern. [SEP]
# INFO:ConZIC:iter 1, The 1-th image: / | [CLS] image of a horse with a grungy pattern. [SEP]
# iter 2, The 1-th image: / | [CLS] image of a horse with a grunge pattern. [SEP]
# INFO:ConZIC:iter 2, The 1-th image: / | [CLS] image of a horse with a grunge pattern. [SEP]
# iter 3, The 1-th image: / | [CLS] image of a horse with a grunge pattern. [SEP]
# INFO:ConZIC:iter 3, The 1-th image: / | [CLS] image of a horse with a grunge pattern. [SEP]
# iter 4, The 1-th image: / | [CLS] image of a horse with a grunge pattern. [SEP]
# INFO:ConZIC:iter 4, The 1-th image: / | [CLS] image of a horse with a grunge pattern. [SEP]
# iter 5, The 1-th image: / | [CLS] image of a horse with a grunge pattern. [SEP]
# INFO:ConZIC:iter 5, The 1-th image: / | [CLS] image of a horse with a grunge pattern. [SEP]
# iter 6, The 1-th image: / | [CLS] image of a horse with a grunge pattern. [SEP]
# INFO:ConZIC:iter 6, The 1-th image: / | [CLS] image of a horse with a grunge pattern. [SEP]
# iter 7, The 1-th image: / | [CLS] image of a horse with a grunge pattern. [SEP]
# INFO:ConZIC:iter 7, The 1-th image: / | [CLS] image of a horse with a grunge pattern. [SEP]
# iter 8, The 1-th image: / | [CLS] image of a horse with a grunge pattern. [SEP]
# INFO:ConZIC:iter 8, The 1-th image: / | [CLS] image of a horse with a grunge pattern. [SEP]
# iter 9, The 1-th image: / | [CLS] image of a horse with a grunge pattern. [SEP]
# INFO:ConZIC:iter 9, The 1-th image: / | [CLS] image of a horse with a grunge pattern. [SEP]
# iter 10, The 1-th image: / | [CLS] image of a horse with a grunge pattern. [SEP]
# INFO:ConZIC:iter 10, The 1-th image: / | [CLS] image of a horse with a grunge pattern. [SEP]
# iter 11, The 1-th image: / | [CLS] image of a horse with a grunge pattern. [SEP]
# INFO:ConZIC:iter 11, The 1-th image: / | [CLS] image of a horse with a grunge pattern. [SEP]
# iter 12, The 1-th image: / | [CLS] image of a horse with a grunge pattern. [SEP]
# INFO:ConZIC:iter 12, The 1-th image: / | [CLS] image of a horse with a grunge pattern. [SEP]
# iter 13, The 1-th image: / | [CLS] image of a horse with a grunge pattern. [SEP]
# INFO:ConZIC:iter 13, The 1-th image: / | [CLS] image of a horse with a grunge pattern. [SEP]
# iter 14, The 1-th image: / | [CLS] image of a horse with a grunge pattern. [SEP]
# INFO:ConZIC:iter 14, The 1-th image: / | [CLS] image of a horse with a grunge pattern. [SEP]
# iter 15, The 1-th image: / | [CLS] image of a horse with a grunge pattern. [SEP]
# INFO:ConZIC:iter 15, The 1-th image: / | [CLS] image of a horse with a grunge pattern. [SEP]
# iter 16, The 1-th image: / | [CLS] image of a horse with a grunge pattern. [SEP]
# INFO:ConZIC:iter 16, The 1-th image: / | [CLS] image of a horse with a grunge pattern. [SEP]
# iter 17, The 1-th image: / | [CLS] image of a horse with a grunge pattern. [SEP]
# INFO:ConZIC:iter 17, The 1-th image: / | [CLS] image of a horse with a grunge pattern. [SEP]
# iter 18, The 1-th image: / | [CLS] image of a horse with a grunge pattern. [SEP]
# INFO:ConZIC:iter 18, The 1-th image: / | [CLS] image of a horse with a grunge pattern. [SEP]
# iter 19, The 1-th image: / | [CLS] image of a horse with a grunge pattern. [SEP]
# INFO:ConZIC:iter 19, The 1-th image: / | [CLS] image of a horse with a grunge pattern. [SEP]
# iter 20, The 1-th image: / | [CLS] image of a horse with a grunge pattern. [SEP]
# INFO:ConZIC:iter 20, The 1-th image: / | [CLS] image of a horse with a grunge pattern. [SEP]
# iter 21, The 1-th image: / | [CLS] image of a horse with a grunge pattern. [SEP]
# INFO:ConZIC:iter 21, The 1-th image: / | [CLS] image of a horse with a grunge pattern. [SEP]
# iter 22, The 1-th image: / | [CLS] image of a horse with a grunge pattern. [SEP]
# INFO:ConZIC:iter 22, The 1-th image: / | [CLS] image of a horse with a grunge pattern. [SEP]
# iter 23, The 1-th image: / | [CLS] image of a horse with a grunge pattern. [SEP]
# INFO:ConZIC:iter 23, The 1-th image: / | [CLS] image of a horse with a grunge pattern. [SEP]
# iter 24, The 1-th image: / | [CLS] image of a horse with a grunge pattern. [SEP]
# INFO:ConZIC:iter 24, The 1-th image: / | [CLS] image of a horse with a grunge pattern. [SEP]
# iter 25, The 1-th image: / | [CLS] image of a horse with a grunge pattern. [SEP]
# INFO:ConZIC:iter 25, The 1-th image: / | [CLS] image of a horse with a grunge pattern. [SEP]
# iter 26, The 1-th image: / | [CLS] image of a horse with a grunge pattern. [SEP]
# INFO:ConZIC:iter 26, The 1-th image: / | [CLS] image of a horse with a grunge pattern. [SEP]
# iter 27, The 1-th image: / | [CLS] image of a horse with a grunge pattern. [SEP]
# INFO:ConZIC:iter 27, The 1-th image: / | [CLS] image of a horse with a grunge pattern. [SEP]
# iter 28, The 1-th image: / | [CLS] image of a horse with a grunge pattern. [SEP]
# INFO:ConZIC:iter 28, The 1-th image: / | [CLS] image of a horse with a grunge pattern. [SEP]
# iter 29, The 1-th image: / | [CLS] image of a horse with a grunge pattern. [SEP]
# INFO:ConZIC:iter 29, The 1-th image: / | [CLS] image of a horse with a grunge pattern. [SEP]
# iter 30, The 1-th image: / | [CLS] image of a horse with a grunge pattern. [SEP]
# INFO:ConZIC:iter 30, The 1-th image: / | [CLS] image of a horse with a grunge pattern. [SEP]
# Finished in 10.143s
# INFO:ConZIC:Finished in 10.143s
# The 1-th image: /
# INFO:ConZIC:The 1-th image: /
# final caption: image of a horse with a grunge pattern.
# INFO:ConZIC:final caption: image of a horse with a grunge pattern.

# %%
# @title Output
Image.open(img_path).show()
print("Final Caption\n")
for i in range(len(FinalCaption_noclip)):
    print(f"{FinalCaption_noclip[i]}\n")
# Out:
# DEBUG:PIL.PngImagePlugin:STREAM b'IHDR' 16 13
# DEBUG:PIL.PngImagePlugin:STREAM b'IDAT' 41 9332
# <PIL.PngImagePlugin.PngImageFile image mode=RGB size=256x256 at 0x7F60433CF730>
# Final Caption
#
# Sample 1: image of a horse with a grunge pattern.
